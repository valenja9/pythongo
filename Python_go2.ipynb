# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/pythongo/blob/main/Python_go2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Valerian je prostě stará škola a neumí s počítači, i když tvrdí, že by se to klidně naučil, jen tím přece nebude ztrácet čas… Výsledek je ale jasný, nechal to na tobě. Asi rozumíš, že to byla jenom rozcvička. Když hledáš ve jménech, tak je potřeba najít nějaké konkrétní jméno…
# ---

# %% [markdown]
# ![logo_sirka_v2_detective_bg_Kreslicí plátno 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Text nahrávky
# ---
# „Je 22. 6. 1994, devatenáct hodin, dvacet minut a sedm sekund. Sedím u počítače a konečně jsem se naučil, jak vypsat ta zpropadená slova! Bohužel ale potřebuju jen jména, která začínají na písmeno J. Právě jsem si všiml, že mám každou ponožku jinou. Pozoruhodné.“

# %%
#@title
from IPython.core.display import display, HTML
import IPython.display as ipd

display(ipd.Audio(f'/content/drive/My Drive/Python go/valerian drake/text_02_B.mp3'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Klikni na ikonu níže ![icona.png](data:image/png;base64,...) vedle nápisu Show Code!, která ti umožní přístup do databáze, kterou budeš potřebovat.

# %%
#@title
#Toto okno musíš spustit.
JMENA = ['Oliver',
 'Jake',
 'Noah',
 'James',
 'Jack',
 'Connor',
 'Liam',
 'John',
 'Harry',
 'Callum',
 'Mason',
 'Robert',
 'Jacob',
 'Michael',
 'Charlie',
 'Kyle',
 'William',
 'William',
 'Thomas',
 'Joe',
 'Json',
 'Ethan',
 'David',
 'George',
 'Reece',
 'Michael',
 'Richard',
 'Oscar',
 'Rhys',
 'Alexander',
 'Joseph',
 'James',
 'Charlie',
 'James',
 'Charles',
 'William',
 'Damian',
 'Daniel',
 'Thomas']

# %% [markdown]
# #Úkol 2.1: Teď potřebuješ vypsat jen jména začínající písmenem "J". Pro tento účel máš už předvytvořený list, který se jmenuje "List_jen_jmen_na_J"! Teď ale musíš napsat kód, který vyfiltruje všechna tyto jména z databáze a uloží je do tohoto předvytvořeného listu.
# ---

# %%
#Zde programuj
List_jen_jmen_na_J = [] 
for jmeno in JMENA:
  pass #nahraď "pass" tvým funkčním kódem
print(List_jen_jmen_na_J)
# Out:
# []

# %% [markdown]
# #Úkol 2.2: Máš to? Vypsal se ti seznam jmen začínajících na J, ale pár se ti jich tam opakuje. Nepřipadá ti to nepřehledné? Nám ano! Teď zredukuj seznam jmen tak, aby tam každé jméno bylo jen jednou!

# %%
#Zde programuj!
print(  )

# %% [markdown]
# # Jak zredukovat list pouze na unikátní výsledky?
# ---
# - Koukni do našich výukových materiálů a zjisti, jak na to https://colab.research.google.com/drive/1hqlBgTHRzEUHtPdAM-Uh1QA2XdXCrkLC?usp=sharing

# %% [markdown]
# #Jak vůbec Python pracuje s textem?
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=6', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=6"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #Jak pracovat s podmínkou?
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=-zctt6ZKzFA&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=7', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=-zctt6ZKzFA&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=7"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #Jak přidávat do listu?
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=bCHjLzEL9Dw&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=9', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=bCHjLzEL9Dw&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=9"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# *Tyto stránky jsou vytvořené spolkem Vzdělání budoucnosti, z.s., jsou chráněny autorským právem a jsou určeny pro osobní použití nebo použití našimi zákazníky. Tyto webové stránky a jakýkoli text, obrázky či jiné komponenty, které obsahují, je zakázáno reprodukovat jinak než jejich stahováním a zobrazováním na jednom počítači.*
#
# *Tato hra je složena z volně dostupných databází, inspirována právem vyplývajícím z 5. dodatku Ústavy Spojených států amerických a není použita pro výdělečné účely.*

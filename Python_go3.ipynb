# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/pythongo/blob/main/Python_go3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Valerian má dobré styky s místní policií, takže pro něj nebylo těžké dostat se do opravdové databáze, ale stačí to, co se naučil, nebo bude potřebovat tvoji pomoc?
# ---

# %% [markdown]
# ![logo_sirka_v2_detective_bg_Kreslicí plátno 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Text nahrávky
# ---
# „Je 22. 6. 1994, dvacet hodin, patnáct minut a třicet sekund. Ještě pořád (!) sedím u počítače, ale konečně se mi podařilo dostat se do policejní databáze. Myslel jsem si, že to bude brnkačka, ale jak se v tom mám proboha vyznat? Potřebuju najít muže, který je obyvatelem Georgie, ale dostal jsem přístup do databáze, kde jsou celé Spojené Státy Americké. Hledám jméno manžela mé klientky… Celý tento případ začíná být podivnější víc a víc… Moje klientka šla totiž do vězení za vraždu právě svého muže, tak proč ho vlastně hledat?! Nezapomněl jsem na něco?! Sakra, proč ten krám nefunguje? Vždyť já jen potřebuju zúžit tu databázi!“

# %%
#@title
from IPython.core.display import display, HTML
import IPython.display as ipd
import os


display(ipd.Audio(f'/content/drive/My Drive/Python go/valerian drake/text_03_B.mp3'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Klikni na ikonu níže ![icona.png](data:image/png;base64,...) vedle nápisu Show Code!, která ti umožní přístup do databáze, kterou budeš potřebovat.

# %%
#@title
import pandas as pd
moje_databaze = pd.read_html("https://www.theguardian.com/sport/datablog/2012/jun/25/olympic-medal-winner-list-data")[0][["Athlete",	"Country"	,"Bronze"]][:300]
moje_databaze.rename(columns={"Athlete": "Jména", "Country":"Země", "Bronze": "Počty přestupků"}, inplace=True)

# %% [markdown]
# #Úkol 3.1:Jména zločinců z databáze ti bohužel Valerian ukázat nemůže. Má přeci jen taky nějakou zodpovědnost. Proto jejich jména a místo původu zašifroval do databáze Olympijských vítězů. Aby jsi mu pomohl, tak vyfiltruj jen jména těch, co pochází z USA!
# ---

# %%
#@title
moje_databaze
# Out:
#                     Jména            Země Počty přestupků
# 0        LATYNINA, Larisa    Soviet Union               4
# 1         PHELPS, Michael   United States               2
# 2      ANDRIANOV, Nikolay    Soviet Union               3
# 3    MANGIAROTTI, Edoardo           Italy               2
# 4            ONO, Takashi           Japan               4
# ..                    ...             ...             ...
# 295           WIDE, Edvin          Sweden               4
# 296             XIONG, Ni           China               1
# 297             YANG, Wei           China             NaN
# 298      ZAMPORI, Giorgio           Italy               1
# 299         ZATOPEK, Emil  Czechoslovakia             NaN
#
# [300 rows x 3 columns]

# %% [markdown]
# #Úkol 3.2: Napiš podmínku, která vyfiltruje jen obyvatele USA. Databáze je uložena pod proměnnou "moje_databaze", už tedy nemusíš nic dalšího načítat (jak popisujeme na začátku videa "Databáze I") a jen použij techniky na práci s pandas.

# %%
#Zde programuj!
upravena_data_jen_z_usa = moje_databaze #Doplň filraci

print(upravena_data_jen_z_usa)
# Out:
# 0          LATYNINA, Larisa
# 1           PHELPS, Michael
# 2        ANDRIANOV, Nikolay
# 3      MANGIAROTTI, Edoardo
# 4              ONO, Takashi
#                ...
# 295             WIDE, Edvin
# 296               XIONG, Ni
# 297               YANG, Wei
# 298        ZAMPORI, Giorgio
# 299           ZATOPEK, Emil
# Name: Jména, Length: 300, dtype: object

# %% [markdown]
# # Jak na to?
# ---

# %% [markdown]
# https://colab.research.google.com/drive/1hqlBgTHRzEUHtPdAM-Uh1QA2XdXCrkLC?usp=sharing

# %% [markdown]
# # Jak na databáze?
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=4', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #A dál?
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=8', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# *Tyto stránky jsou vytvořené spolkem Vzdělání budoucnosti, z.s., jsou chráněny autorským právem a jsou určeny pro osobní použití nebo použití našimi zákazníky. Tyto webové stránky a jakýkoli text, obrázky či jiné komponenty, které obsahují, je zakázáno reprodukovat jinak než jejich stahováním a zobrazováním na jednom počítači.*
#
# *Tato hra je složena z volně dostupných databází, inspirována právem vyplývajícím z 5. dodatku Ústavy Spojených států amerických a není použita pro výdělečné účely.*

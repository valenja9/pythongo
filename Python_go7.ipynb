# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/pythongo/blob/main/Python_go7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Leslie Jason nafingoval svoji smrt a nechal za ni Cassey zavřít do vězení. Pak vzal syna a Angelu a odjel z města.
# ---

# %% [markdown]
# ![logo_sirka_v2_detective_bg_Kreslicí plátno 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Text nahrávky
# ---
# Je 6. 7. 1994, osm hodin, dvě minuty a dvacet sekund. Už mi také ze všeho třeští hlava a musím říct, že v případu Cassey cítím obrovskou nespravedlnost. Většinou vyšetřuju s čistou hlavou a ke svým klientům mám jen profesionální vztah, ale teď cítím, že bych chtěl Cassey opravdu pomoct. Připomíná mi dědečkovu velkou křivdu, když byl ještě u policie… Kdyby se nestala, nikdy by nebyl detektivem, a možná ani já ne… Ale teď se musím věnovat Cassey, čeká mě matematická šifra. Cassey mi poslala tabulku a tuto dvojici souřadnic. Hledání právě začíná! (y5, x4), (y2, x7),(y8, x1). Všechno to prý musím spojit dohromady… Překvapivé zjištění: s počítačem si už poměrně dobře rozumíme, ale nerad bych to zakřiknul.

# %%
#@title
from IPython.core.display import display, HTML
import IPython.display as ipd
import os


display(ipd.Audio(f'/content/drive/My Drive/Python go/valerian drake/text_07_A.mp3'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Klikni na ikonu níže ![icona.png](data:image/png;base64,...) vedle nápisu Show Code!, která ti umožní přístup do databáze, kterou budeš potřebovat.

# %%
#@title
import pandas as pd
nova_data = [[1, 7, 6, 2, 4, 5, 8, 0, 9, 3],
              [9, 3, 7, 0, 1, 2, 8, 6, 5, 4],
              [8, 4, 1, 6, 2, 3, 0, 7, 9, 5],
              [7, 6, 3, 2, 1, 8, 4, 0, 9, 5],
              [5, 4, 2, 8, 6, 3, 1, 9, 7, 0],
              [3, 4, 6, 9, 1, 0, 8, 7, 5, 2],
              [0, 9, 2, 6, 4, 1, 8, 7, 5, 3],
              [8, 6, 2, 1, 4, 3, 9, 0, 5, 7],
              [7, 3, 5, 8, 1, 2, 9, 6, 0, 4],
              [8, 6, 5, 2, 7, 4, 3, 1, 0, 9]]
slovnik_odpovedi_ = {}              
for i in range(0,40):
  if i == 11:
    slovnik_odpovedi_[i] = "Najala jsem si Vás jako soukromého detektiva a teď po Vás chci, abyste mi zjistil, kde žije můj manžel a pod jakým jménem. Příště pošlu Caesarovu šifru"
  else:
    slovnik_odpovedi_[i] = "Špatně! Zkus to znovu."
data_tabulka = pd.DataFrame(nova_data, columns=[f"sloupec_x_{i}" for i in range(0,10)],index=[f"radek_y_{i}" for i in range(0,10)])
data_tabulka
# Out:
#            sloupec_x_0  sloupec_x_1  ...  sloupec_x_8  sloupec_x_9
# radek_y_0            1            7  ...            9            3
# radek_y_1            9            3  ...            5            4
# radek_y_2            8            4  ...            9            5
# radek_y_3            7            6  ...            9            5
# radek_y_4            5            4  ...            7            0
# radek_y_5            3            4  ...            5            2
# radek_y_6            0            9  ...            5            3
# radek_y_7            8            6  ...            5            7
# radek_y_8            7            3  ...            0            4
# radek_y_9            8            6  ...            0            9
#
# [10 rows x 10 columns]

# %% [markdown]
# #Úkol 7.1: Zadej do tabulky názvy řádků a sloupců (y5, x4), (y2, x7),(y8, x1). V tabulce se takto nacházejí 3 čísla, která je třeba sečíst dohromady.
# ---

# %%
#Zde programuj!   
vysledek = data_tabulka.loc[,] + data_tabulka.loc[,] + data_tabulka.loc[,]
print(vysledek)

# %% [markdown]
# #Úkol 7.2: Výsledné číslo zadej do slovníku odpovědí!
# ---

# %%
slovnik_odpovedi_[vysledek]

# %% [markdown]
# # Jak na to?
# ---
# https://colab.research.google.com/drive/1hqlBgTHRzEUHtPdAM-Uh1QA2XdXCrkLC?usp=sharing
#
# <!--
# 1.   Pro pohyb v tabulce používáme  data_tabulka.loc[souradnice_y, souradnice_x]
# 2.   Klic slovniku je cislo! -->

# %% [markdown]
# # Práce s tabulkou
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=5', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=5"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# *Tyto stránky jsou vytvořené spolkem Vzdělání budoucnosti, z.s., jsou chráněny autorským právem a jsou určeny pro osobní použití nebo použití našimi zákazníky. Tyto webové stránky a jakýkoli text, obrázky či jiné komponenty, které obsahují, je zakázáno reprodukovat jinak než jejich stahováním a zobrazováním na jednom počítači.*
#
# *Tato hra je složena z volně dostupných databází, inspirována právem vyplývajícím z 5. dodatku Ústavy Spojených států amerických a není použita pro výdělečné účely.*

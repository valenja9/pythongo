# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/pythongo/blob/main/Python_go5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Valerian zúžil výběr na několik jmen a dostal se do slepé uličky. Co bude dál? Najde nějakou další indicii?
# ---

# %% [markdown]
# ![logo_sirka_v2_detective_bg_Kreslicí plátno 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Text nahrávky.
# ---
# „Je 26. 6. 1994, osmnáct hodin, patnáct minut a osm sekund. Právě jsem vytáhl dnešní poštu. Vím, že už je večer, ale dřív jsem neměl čas. Tento případ mi opravdu dává zabrat. Mezi dopisy je jeden z Ústavního soudu v Atlantě, posílají mi spis. Otevírám obálku nožem na dopisy. Mám ho po dědečkovi. U nás v rodině se traduje, že právě kvůli tomuto noži se dědeček stal detektivem … Zpátky k dopisu! Obsahuje spoustu informací k mému případu. Zatím jsem četl jen očerňující novinové články, takže si naliju kávu a jdu okamžitě číst.“

# %%
#@title
from IPython.core.display import display, HTML
import IPython.display as ipd
import os


display(ipd.Audio(f'/content/drive/My Drive/Python go/valerian drake/text_05_A.mp3'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Dopis z Ústavního soudu v Atlantě
# ---
# Dne 27. 5. 1992 byl zaznamenán podivný případ na jachtě manželů Jasonových. Podle výpovědi Cassey Jasonové měli s manželem nádherný romantický večer, pili víno a bavili se. Cassey velmi rychle usnula.
# Situace, která nastala hned po jejím probuzení, by nenechala chladného nikoho!
# Její muž Leslie Jason nebyl vedle ní.
# Rozespalá Cassey se ho vydala hledat. Přemýšlela nad tím, jestli jí třeba nedělá snídani. Pak ale viděla daleko děsivější scénář! U pultíku s jídlem byla spoustu krve.
# Vyděšená Cassey následovala kapky krve. Byla to hrůza! Během cesty stále volala jméno svého muže. Došla až nahoru na palubu.  Zde krvavá stopa končila a na zemi ležel krvavý nůž.
# Cassey  nepřemýšlela a vystrašeně ho vzala do ruky. Co se stalo s Lesliem?
# Stála tam minutu, možná dvě. V tu chvíli na ni dopadlo světlo z lodi pobřežní služby. Slyšela jen muže, který volá jméno lodi manželského páru.
# Nebyla schopná ze sebe dostat slova. Pak došlo k rychlému sledu situací.
# Policie pátrala po jejím muži Lesliem.
# Bohužel nebyl nikde k nalezení, záchranný člun a vesty byly na lodi. Pokud spadl do vody, tak jeho šance na přežití byly téměř nulové.
# Cassey byla obžalována z vraždy, její právník viděl celou situaci opravdu černě a prosil ji, aby se přiznala kvůli nižšímu trestu. Ale co bude s jejím synem Maxem?
# Cassey měla tříletého chlapečka Maxe a nechtěla, aby jí byl syn zabaven státem!
# Do příběhu nám tedy vstupuje Maxova opatrovnice, nejlepší kamarádka Cassey jménem Angela. Ženy se domluvily, že toto bude nejlepší možné řešení.
# Angela bude syna opatrovat a často chodit za Cassey na návštěvy.  Soud tedy dopadl dle očekávání a nevinná Cassey dostala celkem 6 let.

# %% [markdown]
# #Úkol 5.1: Do slovníku ulož 6 zajímavých informací.
# ---

# %%
#Zde programuj
slovnik_Valerianovych_informaci = {} #Takhle vytvořím nový slovník
slovnik_Valerianovych_informaci["Křesní jméno manželky"] = "Cassey"  #příklad uložené informace

# %% [markdown]
# #Úkol 5.2: Ze slovníku udělej databázy pomocí pandas
# ---

# %%
#Zde programuj
import pandas as pd
pd.DataFrame()

# %% [markdown]
# # Jak na to?
# ---
#
# https://colab.research.google.com/drive/1hqlBgTHRzEUHtPdAM-Uh1QA2XdXCrkLC?usp=sharing
#
# <!-- 1.   slovnik_nejduležitějších_informací["Křesní jméno manželky"] = "Cassey" Takto jednoduše  se předávají informace.  Klíč je v závorce a věta, či hodnota je za rovní se.
# 2.   K těmto informacím je pak možné přistupovat pomocí klíčů slovnik_nejduležitějších_informací["Křesní jméno manželky"]
# 3. https://www.w3schools.com/python/python_dictionaries.asp  tutorial. -->

# %% [markdown]
# # Práce se slovníkem
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=2', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# *Tyto stránky jsou vytvořené spolkem Vzdělání budoucnosti, z.s., jsou chráněny autorským právem a jsou určeny pro osobní použití nebo použití našimi zákazníky. Tyto webové stránky a jakýkoli text, obrázky či jiné komponenty, které obsahují, je zakázáno reprodukovat jinak než jejich stahováním a zobrazováním na jednom počítači.*
#
# *Tato hra je složena z volně dostupných databází, inspirována právem vyplývajícím z 5. dodatku Ústavy Spojených států amerických a není použita pro výdělečné účely.*

# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/pythongo/blob/main/Python_go_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vítej u našeho detektivního příběhu! Pomoz nám rozluštit tuto pavučinu záhad…
# ---
# Dnes se ti dostalo neskutečné cti! Přišel ti do rukou diktafon Valeriana Drakea, jednoho z nejlepších soukromých detektivů v Americe! Valerian Drake rozluštil velmi promyšlené zločiny, ale i zločiny naprosto nepromyšlené… Těch opravdu mazaných bylo ale mnohem víc! Příběh tohoto muže je spletitý a plný dramatických okolností. Co ho vlastně přitáhlo do světa zločinu, je rodinné tajemství…  Každopádně jedno je jisté, Valerian Drake je čestný a hrdý muž a jeho intelekt je opravdu neskutečný, stejně jako jeho schopnost dedukce a zapomínání. Ale dost tlachání! Už bychom měli začít, že? Máme tu uložených několik jmen a jenom ty nám je může vypsat! K čemu by ti to mělo být? Spusť si Valerianův diktafon a zjisti, o co vlastně šlo!

# %% [markdown]
# ![logo_sirka_v2_detective_bg_Kreslicí plátno 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Přehraj Valerianovu zvukovou stopu.
#
# ---

# %% [markdown]
# „Je 22. 6. 1994, osmnáct hodin, dvacet tři minut a padesát sekund. Padesát jedna… Padesát dva… Sedím u počítače a potřebuju se prohrabat databází jmen. Byl jsem najat usvědčenou vražedkyní, abych udělal velice zvláštní práci… Ona samozřejmě tvrdí, že je nevinná, ale to vám řekne každý... Jen vůbec nevím, jak se tady s tím krámem zachází! Já mám rád staré bloky a plnicí pera, počítače bych přenechal někomu jinému, ale stopu najdu jenom tady… Potřebuju vypsat všechna jména….“

# %%
#@title
from IPython.core.display import display, HTML
import IPython.display as ipd
import os
display(ipd.Audio(f'/content/drive/My Drive/Python go/valerian drake/text_01_B.mp3'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Klikni na ikonu níže ![icona.png](data:image/png;base64,...) vedle nápisu Show Code!, která ti umožní přístup do databáze, kterou budeš potřebovat.

# %%
#@title
#Toto okno musíš spustit.
JMENA = ['Oliver',
 'Jake',
 'Noah',
 'James',
 'Jack',
 'Connor',
 'Liam',
 'John',
 'Harry',
 'Callum',
 'Mason',
 'Robert',
 'Jacob',
 'Michael',
 'Charlie',
 'Kyle',
 'William',
 'William',
 'Thomas',
 'Joe',
 'Ethan',
 'David',
 'George',
 'Reece',
 'Michael',
 'Richard',
 'Oscar',
 'Rhys',
 'Alexander',
 'Joseph',
 'James',
 'Charlie',
 'James',
 'Charles',
 'William',
 'Damian',
 'Daniel',
 'Thomas',
 'Jenny',
 'Jason',
'Jackie', 
'Johnny', 
'James', 
'John Frederick', 
'Jon']

# %% [markdown]
# #Úkol 1: V databázi jsou schovaná jména v proměnné "JMENA". Pomocí tzv. FORCYKLU vypiš všechna jména z databáze.
# ---

# %%
#Zde programuj!
for jmeno in JMENA:

# %% [markdown]
# # Rada
# ---
# Nevíš, jak se vytváří FORCYKLUS? Koukni na video, a nebo se koukni na naše materiály: https://colab.research.google.com/drive/1hqlBgTHRzEUHtPdAM-Uh1QA2XdXCrkLC?usp=sharing

# %% [markdown]
# #Jak v Colabu obejít příkaz print?
#
# Colab automaticky vypisuje poslední řádek kódu. Proto není vždy důležité používat funkci PRINT. ;) Ale pokud jsi použil funkci FORCYKLUS, tak funkci PRINT použít musíš.

# %%
jmeno = "jakub"
jmeno
# Out:
# 'jakub'

# %% [markdown]
# # Jak na forcyklus?
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=Bu_w5aVP1jM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=11', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Bu_w5aVP1jM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=11"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# *Tyto stránky jsou vytvořené spolkem Vzdělání budoucnosti, z.s., jsou chráněny autorským právem a jsou určeny pro osobní použití nebo použití našimi zákazníky. Tyto webové stránky a jakýkoli text, obrázky či jiné komponenty, které obsahují, je zakázáno reprodukovat jinak než jejich stahováním a zobrazováním na jednom počítači.*
#
# *Tato hra je složena z volně dostupných databází, inspirována právem vyplývajícím z 5. dodatku Ústavy Spojených států amerických a není použita pro výdělečné účely.*

# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/pythongo/blob/main/Python_go9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Doba, kdy Cassy propustí z vězení a bude moct najít Maxe a manžela Aarona se blíží! Valerian ukryl důležité informace k případu na jedné webové stránce. Dokážeš ji najít?
# ---

# %% [markdown]
# ![logo_sirka_v2_detective_bg_Kreslicí plátno 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Text nahrávky
# ---
# Dne 5.3.1995, Je sedm hodin, pět minut a sedm sekund. Dnes jsem odesílal další šifrovanou zprávu do vězení. Na každou dvaadvacátou pozici jsem ukryl vebovou adresu. Jen jedna znich je něčím zajímavá. Pokud všechno půjde dobře, tak Cassy pustí během tohoto roku na podmínku. Zajímalo by mě jestlí ví možnostech dvojího obvinění. dvojitém obvinění!

# %%
#@title
from IPython.core.display import display, HTML
import IPython.display as ipd
import os


display(ipd.Audio(f"/content/drive/My Drive/Python go/valerian drake/text_09_A.mp3"))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Klikni na ikonu níže ![icona.png](data:image/png;base64,...) vedle nápisu Show Code!, která ti umožní přístup do databáze, kterou budeš potřebovat.

# %%
#@title
data = """arpost.co	active	507	en	3 💰	scraper	19 OK, 1+3 bad, 1.00 seen	True	True	obor - IT	11.2.20 - přidán tag a author
	ascelibrary.org/aerodynamics	active	464	en	4 💰	scraper	20 OK, 1.00 seen	False	True	typ - vědecké články	11.2.19 - přidán autor -dj
	autobild.de	active	78	de	26 💰	scraper	245 OK, 8 bad, 1.00 seen	False	True	obor - automotive	2.1.20 nefunguje lišta na mobilu -tk
	autocar.co.uk	active	317	en	23 💰	scraper	278 OK, 1.00 seen	True	True	obor - automotive	24.1.20 odstraneni odkazu na jine clanky, pridani autora -tk
	autocarindia.com	active	323	en	23 💰	scraper	122 OK, 1.00 seen	True	True	obor - automotive	24.1.20 pridan autor -tk
	auto.cz	active	28	cs	37 💰	scraper	327 OK, 3 bad, 1.00 seen	False	True	obor - automotive	24.1.20 doplnění autora a tagů do scarperu -tk
	https://www.vzdelanibudoucnosti.cz/clanky	active	223	en	24 💰	scraper	140 OK, 4 bad, 1.00 seen	False	False	obor - automotive	15.4.20 opraveno, nove API udaje od J.Valenty -tk
	autoforum.cz	active	13	cs	37 💰	scraper	330 OK, 0+1 bad, 0.97 seen	False	True	obor - automotive	24.1.20 začištěn scraper, přidán autor a tagy -tk
	@autoguide	wontfix	168	en	9 💰	scraper	73 OK, 4 bad, 1.00 seen	True	False	obor - automotive	27.4.20 FIXME - low ok_ratio (14 OK, 22 bad) - scraper often fails [detected between 20.4.20-27.4.20]
	automa.cz	active	113	cs	25 💰	scraper	4 OK, 1.00 seen	False	False	téma - automatizace	11.2.2020 - není autor ani tag -dj
	@automobilemag	wontfix	184	en	24 💰	scraper	194 OK, 154+30 bad, 0.97 seen	False	False	obor - automotive	20.4.20 FIXME - low ok_ratio (38 OK, 36 bad) - scraper often fails; low seen_existing_ratio (0.57) - article collector probably misses some articles [detected between 13.4.20-20.4.20]
	automobil-produktion.de	active	79	de	27 💰	scraper	104 OK, 0+1 bad, 1.00 seen	False	True	obor - automotive	13.1.20 od 5.12.19 neviděl scraper články, změna na straně webu - opravil jsem collector -tk
	automobilrevue.cz	active	26	cs	19 💰	scraper	20 OK, 1.00 seen	True	True	obor - automotive	11.2.20 - přidán autor -dj
	auto-motor-und-sport.de	active	75	de	26 💰	scraper	441 OK, 2+1 bad, 1.00 seen	False	True	obor - automotive	24.1.20 doplnění autora do scarperu -tk
	automototip.cz	active	185	cs	15 💰	scraper	0 OK, 1.00 seen	True	False	obor - automotive	11.2.20 - přidán autor a tagy -dj
	autorevue.cz	active	9	cs	35 💰	scraper	183 OK, 1 bad, 1.00 seen	False	True	obor - automotive	24.1.20 doplnění autora a tagů do scarperu -tk
	autoroad.cz	active	24	cs	39 💰	scraper	38 OK, 1.00 seen	False	True	obor - automotive, téma - smart city	11.2.20 - přidán tag a autor -dj
	autospies.com	active	18	en	30 💰	scraper	251 OK, 0+1 bad, 0.99 seen	False	True	obor - automotive, téma - smart city	29.1.20 přidaná metadata, odebrané "share" -tk
	autoweek.com	active	322	en	22 💰	scraper	100 OK, 1.00 seen	False	True	obor - automotive	27.4.20 Upraven zdroj. Předělání selectorů. -j.v
	autozeitung.de	wontfix	77	de	26 💰	scraper	69 OK, 21+21 bad, 1.00 seen	False	True	obor - automotive	21.8.20 vzdálený server občas přeruší spojení; navýšen počet stahování za den a WONTFIX -tk
	avcr.cz	active	204	cs	28 💰	scraper	16 OK, 1.00 seen	True	False	obor - věda, typ - vědecké články	11.2.20 - nelze oddělit metadata -dj
	bbc.com/news	active	150	en	11 💰	scraper	764 OK, 199+3 bad, 0.97 seen	True	True	média - zahraniční	7.9.20 doplněn scraper dle stránky "https://www.bbc.com/news/world-europe-54046156" -tk
	bbc.com/technology	wontfix	142	en	11 💰	scraper	124 OK, 44 bad, 1.00 seen	True	True	téma - technologie	21.8.20 vyčištěn fulltext, některé články s videem se nestahují, wontfix -tk
	blesk.cz/regiony	active	228	cs	33 💰	scraper	893 OK, 2+1 bad, 1.00 seen	True	True	média - deníky, týdeníky	24.1.20 doplnění tagů do scarperu -tk
	blisty.cz/aktualni	active	237	cs	33 💰	scraper	338 OK, 6+2 bad, 1.00 seen	True	True	média - online	11.2.20 - přidány metadata -dj
	brno-stred.cz	active	415	cs	14 💰	scraper	12 OK, 1.00 seen	False	False	stát - radnice a hejtmanství	11.2.20 - nejsou metadata -dj
	businessworld.cz	active	45	cs	33 💰	scraper	15 OK, 1.00 seen	True	True	téma - akcie	11.2.20 - přidány metadata -dj
	busportal.cz	active	5	cs	22 💰	scraper	70 OK, 1.00 seen	False	True	média - odborná, obor - automotive	11.2.20 - přidány metadata -dj
	buspress.eu	active	31	cs	17 💰	scraper	0 OK, 1.00 seen	False	False	média - odborná, obor - automotive	23.6.20 - články jsou 2-3x / měsíc.
	bydleni.cz/tiskove-zpravy	active	283	cs	25 💰	scraper	26 OK, 1.00 seen	True	False	téma - hobby	nejsou metadata
	bydlet.cz	active	453	cs	2 💰	scraper	87 OK, 1.00 seen	False	True	téma - nemovitosti	12.6.20 predelany selector -j.v
	cad.cz/aktuality	wontfix	263	cs	12 💰	scraper	45 OK, 13+37 bad, 0.75 seen	True	True	téma - technologie	31.8.20 pravidelne obcas spadne, ale dari se stahovat vse, davam WONTFIX -tk
	calla.cz/tiskove-zpravy	fixme	484	cs	9 💰	scraper	1 OK, 0+1 bad, 0.97 seen	False	False	sdružení - neziskovky, téma - ekologie	7.9.20 FIXME - low ok_ratio (0 OK, 1 bad) - scraper often fails [detected between 31.8.20-7.9.20]
	carlist.my	active	324	en	23 💰	scraper	45 OK, 1.00 seen	True	True	obor - automotive	přidány metadata -dj
	carmagazine.co.uk/car-news	active	126	en	26 💰	scraper	24 OK, 1.00 seen	False	True	obor - automotive	přidána metadata -dj
	carmagazine.co.uk/spy-shots	active	127	en	9 💰	scraper	3 OK, 1.00 seen	True	True	obor - automotive	přidány metadata -dj
	carscoops.com	active	20	en	32 💰	scraper	759 OK, 1.00 seen	True	True	obor - automotive, téma - smart city	24.1.20 odebrány vnořené odkazy, přidán autor a tagy -tk
	cbn.com	active	153	en	10 💰	scraper	26 OK, 1.00 seen	True	True	média - zahraniční	přidán autor -dj
	cbtnews.com	active	157	en	10 💰	scraper	129 OK, 0.97 seen	True	True	obor - automotive	přidána metadata -dj
	ceskatelevize.cz/ct24	active	255	cs	32 💰	scraper	932 OK, 1.00 seen	True	True	média - televize a rozhlas	24.4.20 Pridan selector. -jv
	ceskatelevize.cz/tiskove-zpravy	active	164	cs	37 💰	scraper	17 OK, 1.00 seen	True	True	média - televize a rozhlas	nelze oddělit metadata -dj
	ceskenoviny.cz/ekonomika	active	405	cs	3 💰	scraper	257 OK, 1.00 seen	True	False	obor - ekonomika	14.10.19 opraveno, -dj
	ceskykutil.cz	active	281	cs	13 💰	scraper	29 OK, 1.00 seen	True	True	téma - hobby	8.6.20 FIXME - low seen_existing_ratio (0.57) - article collector probably misses some articles [detected between 1.6.20-8.6.20]
	cesky-raj.info	active	345	cs	20 💰	scraper	2 OK, 0+1 bad, 0.97 seen	True	False	téma - turistika	10.8.20 FIXME - no new articles between 11.7.20-10.8.20 - is the source useful? [detected between 3.8.20-10.8.20]
	cfdreview.com	active	208	en	8 💰	scraper	4 OK, 1.00 seen	True	True	téma - CFD	nejsou metadata -dj
	cheb.cz	active	443	cs	19 💰	scraper	53 OK, 3 bad, 1.00 seen	True	True	média - lokální	21.8.20 ok -tk
	chinadaily.com/business	active	138	en	10 💰	scraper	106 OK, 1.00 seen	True	True	média - zahraniční	přidána metadata -dj
	chinadaily.com/business-automotive	active	130	en	10 💰	scraper	71 OK, 1.00 seen	False	True	média - zahraniční, obor - automotive	přidán autor
	chinadaily.com/money	active	141	en	8 💰	scraper	206 OK, 1.00 seen	True	True	média - zahraniční, obor - ekonomika	přidán autor -dj
	chip.cz	active	462	cs	5 💰	scraper	22 OK, 0.95 seen	True	False	média - odborná, obor - IT	29.6.20 FIXME - low seen_existing_ratio (0.57) - article collector probably misses some articles [detected between 22.6.20-29.6.20]
	chomutov-mesto.cz	active	492	cs	3 💰	scraper	7 OK, 1.00 seen	False	False	stát - radnice a hejtmanství	17.8.20 FIXME - no new articles between 18.7.20-17.8.20 - is the source useful? [detected between 10.8.20-17.8.20]
	cityone.cz	active	3	cs	36 💰	scraper	2 OK, 1.00 seen	True	False	téma - smart city, téma - startup	8.2.20 - přidána author metadata -dj
	cmkos.cz	active	365	cs	20 💰	scraper	8 OK, 0.99 seen	True	True	sdružení - komory a svazy	nejsou metadata -dj""".split("\t")

# %% [markdown]
# #Úkol 9: Vytvoř list adres z dat, do kterého uložíš webové adresy z databáze, která je uložená v proměnné "data". Hledané webové adresy se ukrývají na dvaadvacáté pozici indexu. Jedna z nich je speciální!
# ---

# %%
#Zde programuj!
#informace jsou uloženy v proměnné data!
data

# %% [markdown]
# # Jak na to?
#
# https://colab.research.google.com/drive/1hqlBgTHRzEUHtPdAM-Uh1QA2XdXCrkLC?usp=sharing

# %% [markdown]
# # Jak pracovat s rangem?

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=bCHjLzEL9Dw&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=12', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=bCHjLzEL9Dw&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=12"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# *Tyto stránky jsou vytvořené spolkem Vzdělání budoucnosti, z.s., jsou chráněny autorským právem a jsou určeny pro osobní použití nebo použití našimi zákazníky. Tyto webové stránky a jakýkoli text, obrázky či jiné komponenty, které obsahují, je zakázáno reprodukovat jinak než jejich stahováním a zobrazováním na jednom počítači.*
#
# *Tato hra je složena z volně dostupných databází, inspirována právem vyplývajícím z 5. dodatku Ústavy Spojených států amerických a není použita pro výdělečné účely.*

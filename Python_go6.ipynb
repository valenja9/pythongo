# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/pythongo/blob/main/Python_go6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Valerianovi chodily ale i jiná psaní, hlavně od jeho klienty Cassey. Valerian měl ale čím dál vtíravější pocit, jakoby vězeňská služba kontrolovala jejich obsah. Proto se Cassey rozhodla své dopisy šifrovat. Najdi ty správné střípky příběhu!
# ---

# %% [markdown]
# ![logo_sirka_v2_detective_bg_Kreslicí plátno 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Text nahrávky
# ---
# „Je 6. 7. 1994, šestnáct hodin, patnáct minut a čtyřicet sekund. Vzal jsem případ od odsouzené vražedkyně, ale všechno je mnohem složitější, než to vypadalo na začátku. Píšu si s Cassey spoustu dopisů a když se dívám na případ z jejího pohledu, všechno je ale úplně jinak! Dnes mi od ní přišel dlouhý dopis a musel jsem najít správné šifry - třeba kroužkovat a počítat si věty. To, co jsem se dozvěděl, je opravdu znepokojující.“

# %%
#@title
from IPython.core.display import display, HTML
import IPython.display as ipd
import os


display(ipd.Audio(f'/content/drive/My Drive/Python go/valerian drake/text_06_A.mp3'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Klikni na ikonu níže ![icona.png](data:image/png;base64,...) vedle nápisu Show Code!, která ti umožní přístup do databáze, kterou budeš potřebovat.

# %%
#@title
import random
list_odpovědí = 10 * ["Tady je nějaký random text"] + 10 * ["Ve vězení trávím spoustu času čtením knih."] + 10 * ["Pokoušela jsem se utéct z vězení pomocí potrubí!"] + 10 * ["Útěk se mi podařil!"]
random.shuffle(list_odpovědí)
list_odpovědí[1212-1201] = "Pokusila jsem se zavolat své kamarádce Angele, která byla stanovena jako opatrovnice mého syna Maxe. Nevzala mi to. Měly jsme dohodu, že každou druhou sobotu v měsíci mi dá Maxe k telefonu. Byla jsem hrozně nešťastná a vůbec nevěděla, co se děje!"
list_odpovědí[len("python")*2] =  "Angela je učitelka ve škole. Zavolala jsem tedy do školy, kde pracuje, a zjistila jsem, že se přestěhovala. Naštěstí mi dali její novou adresu a telefon."
list_odpovědí[4] =  "Okamžitě jsem se s ní spojila. Překvapená Angela se chvíli snažila odjezd z města zamluvit, ale brzy jí došlo, že znám její nové číslo. Hodně jsem se zlobila a prosila ji, ať mi dá Maxe k telefonu."
list_odpovědí[6378-6370] = "Už to vypadalo, že je všechno v pořádku, když do pokoje vstoupil muž! Angela zděšeně vyhrkla: Leslie, počkej! V tu chvíli se spojení přerušilo a mně začala třeštit hlava!"
list_odpovědí[3] =  "Utekl s Angelou a celé to na mě narafičil! Vymyslel si vraždu a teď mi ještě sebral mého syna."

# %% [markdown]
# #Úkol 6: V dopise (který je uložený v naší databázi pod proměnnou "list_odpovedi") je zašifrováno spoustu důležitých informací. Jsou ukryty pod speciálnímy indexy (pozicemi). Do hranatých závorek (viz video) doplň správné hodnoty a přečti si, co bylo v dopise zašifrováno.

# %%
#Zde programuj!
#Datum Zlaté buly sicilske -1201 
print(list_odpovědí[]) 
#Délka jména našeho programovacího jazyka * 2 
print(list_odpovědí[]) 
#Počet manželek Karla čtvrtého
print(list_odpovědí[])    
#poloměr země v km -6370
print(list_odpovědí[])  
#kolik stěn má třístěn?
print(list_odpovědí[])

# %% [markdown]
# # Jak na to?
# ---
# https://colab.research.google.com/drive/1hqlBgTHRzEUHtPdAM-Uh1QA2XdXCrkLC?usp=sharing

# %% [markdown]
# # Jak se indexuje v listu?
# ---

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=10', width=800, height=550)
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=Rhqg0HgWutM&list=PL1xZNpFaDwilb0AeXr3OAvvmGsW53xMZw&index=10"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# *Tyto stránky jsou vytvořené spolkem Vzdělání budoucnosti, z.s., jsou chráněny autorským právem a jsou určeny pro osobní použití nebo použití našimi zákazníky. Tyto webové stránky a jakýkoli text, obrázky či jiné komponenty, které obsahují, je zakázáno reprodukovat jinak než jejich stahováním a zobrazováním na jednom počítači.*
#
# *Tato hra je složena z volně dostupných databází, inspirována právem vyplývajícím z 5. dodatku Ústavy Spojených států amerických a není použita pro výdělečné účely.*
